# %% [markdown]
# This is a setup script for the 570 project. This program will train a model to detect faces using the WIDER data set, and be able to take in user files to find faces.

# %% [markdown]
# This is some setup code to clone and setup the envirnment for the program. I ran this code using Google Collab Pro, and does require a download and upload of 3.4+ Gb of data to google drive. This will not work well without Collab Pro, and is recommended.

# %% [markdown]
# # Program Setup

# %%
# Mount the drive first
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# This is optional to run, shows if the GPU is being used as well as if the environment is run in High Ram (Google Collab Pro feature)

# %%
# Collab Info
# GPU
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')

# %% [markdown]
# Clone the Repository or Update it, as well as update the required packages

# %%
ls

# %% [markdown]
# This is where i put my directory, but feel free to change this path

# %%
cd /content/drive/My Drive/Colab Notebooks/Project

# %%
ls

# %% [markdown]
# Clone the code from the github rep

# %%
! git clone https://github.com/zdolsen/570Project.git

# %%
ls

# %% [markdown]
# Navigate into the Project Folder

# %%
cd 570Project/

# %%
ls

# %% [markdown]
# If you have not done so by now, make sure you download and install the WIDER dataset. The folder structure should be ....
#
# data ->
# > WIDER->
#
#
#                 wider_face_split
#                 WIDER_test
#                 WIDER_train
#                 WIDER_val
#
# After this, the correct packages can be installed by running the script below

# %%
! pip install -r requirements.txt

# %% [markdown]
# The code is now ready to be run.

# %% [markdown]
# # Running the Program

# %% [markdown]
# The nest step is to test the number of workers that should be used for the version of collab being run. Run The code below and change the number of workers in Main.py to the proper number, with the shortest time

# %%
! make numworkers

# %% [markdown]
# Next, it is time to train the model. This will take quite a bit of time, about 3 hours for each epoch. By default is is set to 10 but you can decrease it by passing in a different epoch argument. You can also resume the training by running
#
# ```
# ! make resume
# ```

# %%
! make train

# %%
! make

# %% [markdown]
# Next you can evaluate the model. This will save the location of the faces for the photos inputted.

# %%
! python3 evaluate.py data/WIDER/wider_face_split/wider_face_test_filelist.txt --dataset-root data/WIDER --checkpoint weights/checkpoint_2.pth --split test

# %%
! make evaluate
